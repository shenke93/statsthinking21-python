# %%
install.packages("NHANES")
# Out:
# package 'NHANES' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\jeuxd\AppData\Local\Temp\RtmpC2h2v1\downloaded_packages

# %%
# Export NHANES data from R package to csv
# To be loaded into Python

library(NHANES)
data(NHANES)
write.csv(NHANES, "../data/NHANES.csv", row.names = FALSE)
